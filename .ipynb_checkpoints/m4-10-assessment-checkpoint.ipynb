# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import requests
import warnings
from sklearn.preprocessing import StandardScaler, OneHotEncoder, label_binarize
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import (train_test_split, cross_validate, cross_val_score,GridSearchCV, StratifiedKFold, learning_curve)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix,ConfusionMatrixDisplay, silhouette_score, roc_curve, auc, 
                             adjusted_rand_score, normalized_mutual_info_score)
from sklearn.inspection import permutation_importance
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Task 1 — Unsupervised Exploration

# %%
df_raw = sns.load_dataset("penguins")
df = df_raw.copy()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
numeric_cols = ['bill_length_mm', 'bill_depth_mm','flipper_length_mm', 'body_mass_g']
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, col in zip(axes.flatten(), numeric_cols):
    sns.histplot(data=df, x=col, hue='species',
                 kde=True, ax=ax)
    ax.set_title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for ax, col in zip(axes.flatten(), numeric_cols):
    sns.boxplot(data=df, y=col, ax=ax)
    ax.set_title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# The feature distributions show clear differences between penguin species, especially in body mass and flipper length. Gentoo penguins generally have larger measurements compared to Adelie and Chinstrap species.
# The boxplots do not show significant extreme outliers, indicating that the dataset is relatively clean and suitable for machine learning tasks.

# %%
features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
X = df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

df_pca = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
df_pca['species'] = df['species'].values

# %%
tsne = TSNE(n_components=2,perplexity=30,random_state=42,n_iter=1000)
tsne_result = tsne.fit_transform(X_scaled)
df_tsne = pd.DataFrame(data=tsne_result, columns=['tsne-1', 'tsne-2'])
df_tsne['species'] = df['species'].values

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))

sns.scatterplot(x='PC1', y='PC2', hue='species', data=df_pca, ax=ax[0])
ax[0].set_title('PCA')
sns.scatterplot(x='tsne-1', y='tsne-2', hue='species', data=df_tsne, ax=ax[1])
ax[1].set_title('t-SNE')

plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans_labels = kmeans.fit_predict(X_scaled)

dbscan1 = DBSCAN(eps=0.5, min_samples=5)
dbscan1_labels = dbscan1.fit_predict(X_scaled)

dbscan2 = DBSCAN(eps=0.8, min_samples=7)
dbscan2_labels = dbscan2.fit_predict(X_scaled)

# %%
print(f"K-Means Silhouette Score: {silhouette_score(X_scaled, kmeans_labels):.3f}")
print(f"DBSCAN (eps=0.5) Silhouette Score: {silhouette_score(X_scaled, dbscan1_labels):.3f}")
print(f"DBSCAN (eps=0.8) Silhouette Score: {silhouette_score(X_scaled, dbscan2_labels):.3f}")
# Out:
# K-Means Silhouette Score: 0.446
# DBSCAN (eps=0.5) Silhouette Score: 0.252
# DBSCAN (eps=0.8) Silhouette Score: 0.474

# %%
true_labels = df['species'].astype('category').cat.codes

ari = adjusted_rand_score(true_labels, kmeans_labels)
nmi = normalized_mutual_info_score(true_labels, kmeans_labels)

print(f"Adjusted Rand Score (ARI): {ari:.3f}")
print(f"Normalized Mutual Information (NMI): {nmi:.3f}")
# Out:
# Adjusted Rand Score (ARI): 0.799
# Normalized Mutual Information (NMI): 0.790

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
sns.scatterplot(x=pca_result[:,0], y=pca_result[:,1], hue=df['species'], ax=ax[0], palette='viridis')
ax[0].set_title('Real Species')
sns.scatterplot(x=pca_result[:,0], y=pca_result[:,1], hue=kmeans_labels, ax=ax[1], palette='tab10')
ax[1].set_title('K-Means Clustering (k=3)')

plt.show()

# %% [markdown]
# PCA and K-Means both found three clear groups in the data.
# K-Means worked well — it got a Silhouette Score of 0.446 and
# an Adjusted Rand Score of 0.799, which means it mostly matched
# the real species labels. The hardest part was separating Adelie
# and Chinstrap penguins, because their body sizes are very similar.
# DBSCAN was less useful here — it marked many points as noise
# instead of putting them in groups. Overall, unsupervised methods
# can find the main structure, but they are not perfect without labels.

# %% [markdown]
# # Task 2 — Supervised Model Pipeline

# %%
df_clean = df_raw.dropna()

X = df_clean.drop("species", axis=1)
y = df_clean["species"]

num_features = X.select_dtypes(include=['float64', 'int64']).columns
cat_features = X.select_dtypes(include=['object']).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(), cat_features)
    ])

# %%
models = {
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "RandomForest": RandomForestClassifier(random_state=42),
    "SVC": SVC(probability=True)
}

metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = {}
for name, model in models.items():
    pipe = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', model)])
    cv_results = cross_validate(pipe, X, y, cv=cv, scoring=metrics)
    results[name] = {m: cv_results[f'test_{m}'].mean() for m in metrics}

df_results = pd.DataFrame(results).T
print(df_results)

best_model_name = df_results['f1_macro'].idxmax()
print(f"Best Model: {best_model_name}")
# Out:
#                     accuracy  precision_macro  recall_macro  f1_macro
# LogisticRegression   0.99403         0.995833      0.989744  0.992294
# RandomForest         0.99100         0.988643      0.990274  0.989133
# SVC                  0.99403         0.995833      0.989744  0.992294
# Best Model: LogisticRegression

# %%
param_grid = {
    'classifier__C': [0.1, 1, 10],
    'classifier__kernel': ['linear', 'rbf'],
    'classifier__gamma': ['scale', 'auto']
}

full_pipe = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', SVC(probability=True, C=1, kernel='rbf'))])

grid_search = GridSearchCV(full_pipe, param_grid, cv=cv, scoring='f1_macro')
grid_search.fit(X, y)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best CV Score (F1): {grid_search.best_score_:.4f}")

default_f1 = df_results.loc["SVC", "f1_macro"]
print(f"Default Model F1: {default_f1:.4f}")
print(f"Improvement: {grid_search.best_score_ - default_f1:.4f}")
# Out:
# Best Parameters: {'classifier__C': 0.1, 'classifier__gamma': 'scale', 'classifier__kernel': 'linear'}
# Best CV Score (F1): 0.9962
# Default Model F1: 0.9923
# Improvement: 0.0039

# %% [markdown]
# Three models were tested: Logistic Regression, Random Forest,
# and SVC. All three gave very high scores — around 99% accuracy
# in cross-validation. Logistic Regression had the best F1 score,
# so it was chosen as the best model. GridSearchCV was used to tune
# the SVC model with different values for C, kernel, and gamma.
# The tuned model did not improve much, because the default settings
# were already strong.

# %% [markdown]
# # Task 3 — Model Evaluation & Interpretation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)
best_model = grid_search.best_estimator_
best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        29
#    Chinstrap       1.00      1.00      1.00        14
#       Gentoo       1.00      1.00      1.00        24
#
#     accuracy                           1.00        67
#    macro avg       1.00      1.00      1.00        67
# weighted avg       1.00      1.00      1.00        67

# %%
ConfusionMatrixDisplay.from_estimator(best_model, X_test, y_test, cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# The confusion matrix shows that the model classified all penguin species correctly on the test set, achieving perfect classification performance.
# No misclassifications were observed between Adelie, Chinstrap, or Gentoo species.

# %%
y_test_bin = label_binarize(y_test, classes=best_model.classes_)
n_classes = y_test_bin.shape[1]

y_score = best_model.decision_function(X_test)

plt.figure(figsize=(8, 6))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve of class {best_model.classes_[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (One-vs-Rest)')
plt.legend()
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    best_model, X, y, cv=5, train_sizes=np.linspace(0.1, 1.0, 10), scoring='f1_macro'
)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, np.mean(train_scores, axis=1), 'o-', label='Training Score')
plt.plot(train_sizes, np.mean(test_scores, axis=1), 's-', label='Cross-validation Score')
plt.title('Learning Curves (SVC)')
plt.xlabel('Training Set Size')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
result = permutation_importance(best_model, X_test, y_test, n_repeats=10, random_state=42)

sorted_idx = result.importances_mean.argsort()

plt.figure(figsize=(10, 6))
plt.barh(X.columns[sorted_idx], result.importances_mean[sorted_idx])
plt.xlabel("Permutation Importance (Decrease in F1 Score)")
plt.title("Feature Importance - Which features drive predictions?")
plt.show()

# %% [markdown]
# The learning curves show that training and test scores are both
# high and close together, so the model is not overfitting or
# underfitting. The hardest species to classify is Chinstrap,
# because its measurements overlap with Adelie. The most important
# features are bill_length_mm and bill_depth_mm — removing them
# causes the biggest drop in score. There is no data leakage,
# because the test set was separated before any training happened.

# %%
joblib.dump(grid_search.best_estimator_, 'penguin_model.pkl')
print("Model saved as penguin_model.pkl")
# Out:
# Model saved as penguin_model.pkl

# %%
url = "http://127.0.0.1:5000/predict"
sample_data = {
    "island": "Biscoe",
    "bill_length_mm": 45.0,
    "bill_depth_mm": 15.0,
    "flipper_length_mm": 210.0,
    "body_mass_g": 4800.0,
    "sex": "Male"
}

response = requests.post(url, json=sample_data)
print("Valid Request Response:", response.json())

invalid_data = {"bill_length_mm": "səhv data"}
response_error = requests.post(url, json=invalid_data)
print("Invalid Request Response:", response_error.json())
# Out:
# Valid Request Response: {'predicted_species': 'Gentoo', 'probabilities': {'Adelie': 0.05686706130088256, 'Chinstrap': 0.01420563043632847, 'Gentoo': 0.928927308262789}}
# Invalid Request Response: {'error': "columns are missing: {'sex', 'island', 'body_mass_g', 'flipper_length_mm', 'bill_depth_mm'}"}

# %% [markdown]
# The model was saved using joblib and served with a Flask API.
# The API has two endpoints: GET /health checks if the server
# is running, and POST /predict takes penguin measurements and
# returns a predicted species with probabilities. Input must be
# JSON with six fields: island, bill_length_mm, bill_depth_mm,
# flipper_length_mm, body_mass_g, and sex. If the input is wrong
# or missing, the API returns a clear error message.
